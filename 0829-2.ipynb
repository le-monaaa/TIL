# %% [markdown]
# # 완전검색, 그리디
#
# - 반복, 재귀
#
# - 완전검색기법
#
# - 순열
#
# - 부분집합
#
# - 조합
#
# - 탐욕 알고리즘
#
# - 활동 선택 문제
#
# - baby-jin

# %% [markdown]
# ### 반복과 재귀
#
# - 반복과 재귀는 유사한 작업을 수행할 수 있다
#
# - 반복: 수행하는 작업이 완료될 때 까지 반복
#
# - 재귀: 주어진 문제의 해를 구하기 위해 동일하나 더 작은 문제의 해를 이용하는 방법.
#
#
# **반복구조**
#
# - 초기화: 반복되는 명령문을 실행하기 전에 (한 번만) 조건 검사에 사용할 변수의 초기값 설정
#
# - 조건검사
#
# - 명령문 실행
#
# - 업데이트: 무한 루프가 되지 않게 조건이 false가 되게 함
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **반복을 이용한 선택정렬**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **재귀적 알고리즘**
#
# 재귀적 정의는 두 부분으로 나뉜다.
#
# - 하나 또는 그 이상의 기본 경우(basis case or rule)
#
#     : 집합에 포감되어 있는 원소로 induction을 생성하기 위한 시드(seed)역할
#
# - 하나 또는 그 이상의 유도된 경우(inductive case or rule)
#
#     : 새로운 집합의 원소를 생성하기 위해 결합되어지는 방법
#
#
# ### 재귀 함수
#
# 함수 내부에서 직접 혹은 간접적으로 자기 자신을 호출하는 함수
#
# 일반적으로 재귀적 정의를 이용해 재귀 함수를 구현함
#
# 기본 부분(basis part)와 유도 부분(indctive part)로 구성됨
#
# 재귀적 프로그램을 작성하는 것은 반복 구조에 비해 간결하고 이해하기 쉬움
#
# 함수 호출은 프로그램 메모리 구조에서 스택 사용. --> 반복적인 스택 사용으로 메모리 및 속도에서 성능저하 발생
#
# -- 팩토리얼 재귀 함수
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# **문제 해결에 있어서 재귀와 반복의 선택**
#
# 재귀- 문제 해결을 위한 알고리즘 설계가 간단하고 자연스럽다(추상자료형-list, tree 등의 알고리즘에서는 재귀적 구현이 간단하고 자연스러운 경우가 많음)
#
# 하지만 재귀적 알고리즘은 반복 알고리즘보다 더 많은 메모리와 연산을 필요로 한다.
#
# 입력값이 커질수록 재귀 알고리즘은 반복에 비해 비효율적일 수 있음
#
#
# **반복과 재귀의 비교**
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
# 2k연산

# %%
# 연습문제 1: 선택 정렬 함수를 재귀적 알고리즘으로 작성해 보시오

# %% [markdown]
# ### 완전 검색 기법
#
# #### brute-force
#
# 대부분의 문제에 적용 가능. 상대적으로 빠른 시간에 알고리즘 설계 가능
#
# 문제에 포함된 자료(요소, 인스턴스)의 크기가 작다면 유용함. 알고리즘의 효율성을 판단하기 위한 척도로 사용됨
#
# **Brute-Force 탐색**
#
#     자료들의 리스트에서 키 값을 찾기 위해서 첫번째 자료부터 비교하면서 진행
#
#    ![image.png](attachment:image.png)
#
#    모든 경우의 수를 생성하고 테스트함-> 수행속도 느림 but 답을 찾을 확률 큼
#
#    그리디 기법이나 동적 계획법 이용, 효율적인 알고리즘 찾을 수 있음
#
#    --문제를 해결할 때, 완전 검색 기법으로 접근해 답을 도출한 후, 성능 개선을 위해 다른 알고리즘 적용해보기
#
#    ![image-2.png](attachment:image-2.png)
#
#
# **완전 검색**
#
#     많은 종류의 문제들이 특정 조건을 만족하는 경우나 요소를 찾는 것.
#
#     순열(permutation), 조합(combination), 부분집합(subsets) 과 같은 조합적 문제들과 연관됨
#
#     ===> 완전 검색은 조합적 문제에 대한 brute-force 방법이다

# %% [markdown]
# ### 순열 (permutation)
#
# 서로 다른 것 들 중 몇 개를 뽑아 한 줄로 나열하는 것
#
# 서로 다른 n개 중 r개를 택하는 순열
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# - 단순하게 순열을 생성하는 방법
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# 재귀 호출을 통한 순열 생성
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-10.png](attachment:image-10.png)

# %% [markdown]
# ### 부분집합
#
# 38
# 집합에 포함된 원소를 선택하는 것
#
# N개의 원소를 포함한 집합에서 모든 부분집합의 개수는 2^n개.
#
# 단순하게 모든 부분 집합 생성하는 방법
# - 4개 원소를 포함한 집합에 대한 power set 구하기
# ![image.png](attachment:image.png)
