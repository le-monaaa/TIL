# %% [markdown]
# ### Classes
#
# #### 절차지향 프로그래밍
# : 프로그램을 "데이터"와 "절차"로 구성하는 방식의 프로그래밍 패러다임
#
# **절차지향 프로그래밍 특징**
# - 데이터와 해당 데이터를 처리하는 함수(절차)가 분리되어 있으며, 함수 호출의 흐름이 중요
# - 코드의 순차적인 흐름과 함수 호출에 의해 프로그램이 진행
#
# - 데이터 재사용보다는 처음부터 끝까지 실행되는 결과물이 중요한 방식
# - 실제로 실행되는 내용이 무엇이 무엇인가가 중요
#
# **소프트웨어 위기**
# - 하드웨어의 발전으로 컴퓨터 계산용량, 문제의 복잡성이 급증해 소프트웨어에 발생한 충격
#
# #### 객체지향 프로그래밍
# - 데이터와 해당 데이터를 조작하는 메서드(함수)를 하나의 객체로 묶어 관리하는 방식의 프로그래밍 패러다임
#
# ![image.png](attachment:image.png)
#
# 절차지향: 데이터가 그냥 인자로 들어가는 상황
# 객체지향: 공통요소를 상위요소에 부여. 하위 요소에서 커스터마이징.
#
# **절차지향**
# - 데이터와 해당 데이터를 처리하는 함수(절차)가 분리
# - 함수 호출의 흐름이 중요
# 함수(데이터)
#
# **객체지향**
# - 데이터와 해당 데이터를 처리하는 메서드(메시지)를 하나의 객체(클래스로 묶음)
# - 객체 간 상호작용과 메시지 전달이 중요.
# 데이터(객체).메서드
#
# 절차지향의 주체는 함수. 객체지향의 주체는 데이터. 주체가 반대가 됨
# ex. list.append() list라는 데이터가 append라는 메서드 호출.
# () -> 메서드. 함수
#
#
# #### class
#
# 파이썬에서 타입을 표현하는 방법.
# - 객체를 생성하기 위한 설계도
# - 데이터와 기능을 함께 묶는 방법을 제공
#
# #### 객체
#
# 클래스에서 정의한 것을 토대로 메모리에 할당된 것. 함수, 변수, ... 파이썬에서 사용하는 모든것들이 객체다
# "속성"과 "행동"으로 구성된 모든 것. 변수(속성)와 메서드(행동) 두가지로 나뉨.
#
# 클래스로 만든 객체를 인스턴스라고도 함.
#
# a는 객체다 o
# a는 인스턴스다 x
# a는 클래스 b의 인스턴스다 o
#
# 인스턴스는 관계사이에서 적용되는 말.
#
# 클래스를 만든다 == 타입을 만든다.
#
# 우리가 사용하는 모든 데이터 타입은 클래스이다. str, list, tuple, dict, ...
#
#
# "hello".upper()
# 문자열.대문자로변환()
# 객체.행동()
# 인스턴스.메서드() 인스턴스가 메서드 호출.
#
# **객체의 특징**
# - 타입 : 어떤 연산자(operater)와 조작(method)이 가능한가?
# - 속성 : 어떤 상태(data)를 가지는가?
# - 조작법 : (method) : 어떤 행위(function)를 할 수 있는가?
#
# 객체 = 속성 + 기능

# %%
# 클래스 정의
class Person:
    #속성(변수)
    blood_color = "red"

    #메서드
    def __init__(self, name): #개발자가 직접 호출하지 않는 부분. init = 초기화
        self.name = name #init => 생성자. 인스턴스 생성시 자동호출.
        #초깃값을 줄 수도 있고 안 줄 수도 있다.

    def singing(self):
        return f"{self.name}가 노래합니다"
    
# 인스턴스 생성
singer1 = Person("iu") #위치인자 name에 대한 인자
singer2 = Person("BTS")

# 메서드 호출
print(singer1.singing())
print(singer2.singing())

# 속성(변수) 사용
print(singer1.blood_color)
print(singer2.blood_color)
# 결괏값 같음. 같은 클래스를 참고했기 때문에.
# 하지만 둘의 name은 다르다.

# %% [markdown]
# **생성자 함수**
#  객체를 생성할 때 자동으로 호출되는 특별한 메서드
#  __init_\_이라는 이름의 메서드로 정의됨, 객체 초기화
#  생성자 함수를 통해 인스턴스를 생성하고 필요한 초기값을 설정
#
#  **인스턴스 변수**
#  인스턴스(객체)마다 별도로 유지되는 변수
#  인스턴스마다 독립적인 값을 가지며, 인스턴스가 생성될 때마다 초기화됨.
#
# **클래스 변수**
#  클래스 내부에 선언된 변수
#  클래스로 생성된 모든 인스턴스들이 공유하는 변수
#
# **인스턴스 메서드**
#  각각의 인스턴스에서 호출할 수 있는 메서드
#  인스턴스 변수에 접근, 수정하는 등의 작업을 수행
#
#
#  **클래스와 인스턴스 간의 이름 공간**
#  - 클래스 정의하면 클래스와 해당하는 이름 공간 생성
#  - 인스턴스 만들면, 인스턴스 객체가 생성되고 독립적인 이름 공간 생성
#  - 인스턴스에서 특정 속성에 접근하면, 인스턴스 ->클래스 순으로 탐색
#
#
# ![image.png](attachment:image.png)
#
# 인스턴스 변수는 클래스가 신경쓸 게 아님. 그렇기 때문에 클래스에 정의되지 않아도 생성 가능.
# 메서드를 만들 수는 없음.
#
#
# **독립적 이름공간을 가지는 이점**
# - 각 인스턴스는 독립적인 메모리 공간을 가지며, 클래스와 다른 인스턴스 간에는 서로의 데이터나 상태에 직접적인 접근이 불가능
# - 객체 지향 프로그래밍의 중요한 특성 중 하나로, 클래스와 인스턴스를 모듈화하고 각각의 객체가 독립적으로 동작하도록 보장.
# - 이를 통해 클래스와 인스턴스는 다른 객체들과의 상호작용에서 서로 충돌이나 영향을 주지 않으면서 독립적으로 동작할 수 있음
# - 코드의 가독성, 유지보수성, 재사용성을 높이는 데 도움을 줌
#
# #### 인스턴스 변수와 클래스 변수
#
# - 인스턴스의 수를 확인하고 싶다면? : 인스턴스가 생성 될 때마다 클래스 변수가 늘어나도록 설정할 수 있음
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# 클래스변수 변경 방법 : 클래스.클래수변수 =
#
# 클래스 변수와 같은 이름의 인스턴스 변수 생성 -> 본인만의 변수 만든 것(새로운 인스턴스 변수 생성). 클래스 변수에 영향은 없다.
#
# 클래스 변수에 접근할 때는 인스턴스 변수를 통하는것보다 그냥 클래스 변수를 바로 호출하는게 정확하다. (위의 경우처럼 값이 바뀌었을 경우)
# c1.taste
# Cookie.taste

# %%
class Cookie:
    def __init__(self, taste):
        self.taste = taste # self.taste는 self 인스턴스 내의 변수. taste는 받은 인자

    #생성자 함수를 만들지 않으면 파이썬이 만들어주는 생성자 함수
    # def __init__(self):
    #     pass
    
    #초기에 실행하고 싶은게 있다면 생성자 함수에 넣기.
    #생성자 함수도 일종의 인스턴스 메서드

c1 = Cookie("Chocolate")
c2 = Cookie("Cheese")


print(c1.taste)
print(c2.taste)
# class Animal:
    # pass
# 굳이 생성자 함수 없어도 값을 넣어줄 수 있음(인스턴스 생성 가능)

# %% [markdown]
# #### 메서드
# - 인스턴스 메서드/ 인스턴스.메서드() 인스턴스가 호출하는 메서드
# - 클래스 메서드/ 클래스.메서드() 클래스가 호출하는 메서드
# - 정적 메서드
#
# **인스턴스 메서드**
#
# 클래스로부터 생성된 각 인스턴스에서 호출할 수 있는 메서드. 인스턴스의 상태를 조작하거나 동작을 수행
# [1, 2, 3].append()
# - 클래스 내부에 정의되는 메서드의 기본
# - 반드시 첫 번째 매개변수로 self(인스턴스 자신)을 전달받음. 다른이름도됨. self를 쓰는건 암묵적인 룰. 쓸 수 있지만 다른거 안써요

# %%
# 인스턴스.메서드()
"abc".upper()

# 클래스.메서드(인스턴스 자기자신)
str.upper("abc")
#실제 파이썬 내부 동작은 이렇게 이루어짐.
# str 클래스가 upper 메서드를 호출했고, 그 첫번째 인자로 문자열 인스턴스가 들어간 것
# 인스턴스 메서드의 첫번째 매개변수가 반드시 자기자신인 이유.

# 같은 건데 아래의 축약이 위.
# 아래는 데이터가 인자로써 들어가는것 위는 데이터가 메서드를 호출
# self를 쓰는 이유. 인스턴스 메서드가 자기 자신을 제일 먼저 인자로 받는 이유
# self 정의 x -> 아래방법으로만 실행해야 함.

# %% [markdown]
# **self 동작 원리**
# 단축형 호출. 객체가 단순히 어딘가의 함수로 들어가는 인자가 아닌 객체 스스로 메서드를 호출하여 코드를 동작하는 객체 지향적 표현
#
# #### 생성자 메서드
# 인스턴스 객체가 생성될 때 자동으로 호출되는 메서드.
# -> 인스턴스 변수들의 초기값 설정
# 파이썬이 알아서 해주지만 그래도 명시적으로 써주는게 좋다.
#
# #### 클래스 메서드
# 클래스가 호출하는 메서드. 클래스 변수를 조작하거나 클래스 레벨의 동작을 수행.
#
# @calssmethod 데코레이터로 정의
# 호출 시, 첫번째 인자로 호출하는 클래스(cls)가 전달됨
# 클래스 메서드이기 때문에 메서드 내 호출하는 첫번째 인자는 cls이다.(self)
# 첫번째 인자로 클래스를 받기 때문에 조작하기가 편함. cls.변수 = ~~
#
# 클래스 변수는 클래스 메서드로 쓰는게 기능 상 깔끔하다.
#
# ![image.png](attachment:image.png)
#
# Q. classmethod에 cls 말고 person넣으면 안되나요?
# A. 상속때문에.
#     person으로 고정시켜버리면 자식클래스에서 이 클래스를 호출할 때 본인의 count가 아니라
#     person의 카운트를 세버림
#
# #### 스태틱 메서드
#
# 클래스와 인스턴스와 상관없이 독립적으로 동작하는 메서드
# 주로 클래스와 관련이 있지만 인스턴스와 상호작용이 필요하지 않은 경우에 사용
#
# @staticmethon 데코레이터로 정의
# 호출 시 필수적으로 작성해야 할 매개변수 x
# 객체 상태나 클래스 상태 수정 불가. 단지 기능(행동)만을 위한 메서드.
# 클래스에도, 인스턴스에도 영향을 주지 않는
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **인스턴스 메서드** : self. 인스턴스 상태 변경, 인스턴스의 특정 동작 수행
# **클래스 메서드** : cls. 인스턴스 상태에 의존하지 않는 기능정의. 클래스변수 조작, 클래스 레벨의 동작 수행
# **스태틱 메서드** : x. 클래스, 인스턴스와 관련이 없는 일반적인 기능을 수행
# 객체를 만들 필요가 없는 메소드에 사용
#
# **지향**
# 인스턴스 - 인스턴스 매서드 호출
# 클래스 - 클래스메서드, 정적메서드 호출
#
# 클래스는 모든 메서드를 호출할 수 있음
# 하지만 클래스는 클래스 메서드, 정적 메서드만 사용하도록한다.
#
# 인스턴스도 모든 메서드를 호출 할 수 있음
# 하지만 인스턴스는 인스턴스 메서드만 사용하도록
#
#
# **매직 메서드**
# ![image.png](attachment:image.png)
#
# __str_\_
# 출력문 변경 가능
# ![](attachment:image-2.png)
#
# **데코레이터**
#  다른 함수의 코드를 유지한 채로 수정하거나 확장하기 위해 사용되는 함수
# 아래 함수가 데코레이터의 인자로 들어가는 느낌
# 원본 함수의 기능을 꾸며준다~
#
# ### 절차지향과 객체지향은 대조되는 개념이 아니다
# 객체지향은 기존 절차지향을 기반으로 두고 보완하기 위해 객체라는 개념을 도입해 상속, 코드 재사용성, 유지보수성 등의 이점을 가지는 패러다임
