# %% [markdown]
# pjt 08
#
# # Django에서 알고리즘 구현 및 성능 측정
#
# **목표**
#
# django에서 요구사항에 따라 알고리즘을 구현해보고 구현한 알고리즘의 성능 측정한다.
#
# Locust 툴을 이용한 성능 테스트
#
#
# 1. 테스트 & 성능 테스트의 개념
# 2. Locust 세팅
# 3. 정렬 알고리즘 성능 측정 실습

# %% [markdown]
# ## 테스트
#
# **테스트란?**
#
# 원하는 기능이 모두 구현되었는지 확인하고 숨겨져있는 결함을 찾는 활동
#
# 여러가지 도구들을 활용하여 버그를 찾아내고 신뢰성, 보안, 성능 등을 검증하는 중요한 단계
#
# -- 상황에 맞게 필요한 테스트를 진행해야 한다-> 검색을 통해 필요한 테스트를 찾아 한다
#
#
# **성능 테스트**
#
# 핵심적인 테스트 중 하나. 특정 상황에서 시스템이 어느 정도 수준을 보이는가 혹은 어떻게 대처를 하는가를 테스트하는 과정.
#
# - 목적
#
#   여러 테스트를 통해 성능 저하가 발생하는 요인을 발견하고 제거. 출시 전 발생할 수 있는 위험과 개선사항을 파악. 안정적이고 신뢰할 수 있는 제품을 빠르게 만들기 위해서.
#
# 부하 테스트, 스트레스 테스트

# %% [markdown]
# **부하 테스트** Load testing
#
# 시스템에 임계점의 부하가 계속될 때 문제가 없는가? 시스템의 신뢰도와 성능 측정이 목적
#
#
# **스트레스 테스트** stress test
#
# 시스템에 과부하가 올 때의 동작 테스트. 장애 조치과 복구 절차가 효과적이고 효율적인지 확인하는 것이 목적
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## API 성능 테스트
#
# **Locust**
#
# 오픈 소스 부하 테스트 도구. 수많은 사용자들이 동시에 들어올 때 어떤 일이 벌어지는지를 확인하는 부하 테스트를 할 수 있음.
# 파이썬 언어로 테스트 시나리오를 간편하게 작성 가능. 결과를 웹에서 확인할 수 있는 UI 지원
#
# https://docs.locust.io/en/stable/
#
#
# ![image-2.png](attachment:image-2.png)
#
# RPS(request/sec) 성공한 요청 수
#
#
# ![image-3.png](attachment:image-3.png)
#
# ![image.png](attachment:image.png)
#
# ![image-4.png](attachment:image-4.png)
#
# 95per에 해당하는 요청에 응답하는 데 걸린 시간이 얼마나 되는지.
# 점점 서버에 부하가 온다. 요청이 처리하는 수보다 점점 많아져서(처리해야 할 수가 누적됨) 병목현상 발생.
#
#
# ![image-5.png](attachment:image-5.png)
#
# 동시접속자 수
