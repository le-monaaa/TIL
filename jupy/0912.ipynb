# %% [markdown]
# # Django
#
# Framework : 웹 애플리케이션을 빠르게 개발할 수 있도록 도와주는 도구
#
#             (개발에 필요한 기본 구조, 규칙, 라이브러리 등을 제공)
#
#
# **Django**
#
# python 기반의 대표적인 웹 프레임워크
#
# client : 서비스를 요청하는 주체 (웹 사용자의 인터넷이 연결된 장치, 웹 브라우저)
#
# Server : 클라이언트의 요청에 응답하는 주체
#
# ![Alt text](image-1.png)
#
# 가상 환경 : python 애플리케이션과 그에 따른 패키지들을 격리하여 관리할 수 있는 독립적인 실행 환경
#
# ![Alt text](image-2.png)
#
# **가상환경 생성**
#
# ![Alt text](image-3.png)
# \$ python -m venv (가상환경이름)
#
# **가상환경 활성화**
#
# \$ source venv/Scripts/activate
#
# ![Alt text](image-4.png)
#
# (venv) 가 나옴 -> 내가 어느 가상환경에 있는지, 어떤 가상환경이 활성화 되어있는지 확인
#
# 가상환경은 이동하는 개념이 아니라 우리가 on/off하는 개념이라고 받아들여야함!!
#
# off command : deactivate
#
# **환경에 설치된 패키지 목록 확인**
#
# 현재 환경에 있는 패키지 목록.
# \$ pip list
#
# 앞서 생성했던 venv(가상환경명)을 activate 하고 pip list를 입력해보면 설치되어 있는 패키지 목록이 다름을 알 수 있다
# (가상환경의 독립성)
#
# ![Alt text](image-5.png)
#
# ![Alt text](image-6.png)
#
# git hub에 가상환경 파일이 아닌 pip list freeze한 파일을 올려준다.
#
# 가상환경 파일은 gitignore에 추가!!
#
# gitignore.io에서!
#
#
# 받는사람은? 하나하나 설치X 한번에 설치하는 명령어가 있습니당
#
# 해당 txt 파일을 받고, 가상환경 만든 후에
#
# pip install -r (파일명).txt
#
# 하면 알아서 읽으면서 설치해줌
#
# 패키지 목록이 갱신될때마다 새로 작성.
#
# 참고 https://married-spot-253.notion.site/Python-89514730def04096b9b42b4824c50967
#
# https://www.djangoproject.com/
#
#
# **Django 프로젝트 생성**
#
# ![Alt text](image-7.png)
#
# ![Alt text](image-8.png)
#
# ![Alt text](image-9.png)
#
# 종료 cntl + c **터미널 강제종료하지않기!!!!**
#
#
# **Django 프로젝트 생성 루틴 정리**
#
# ![Alt text](image-10.png)
#
#
#
# **LTS(Lon-term support)**
#
# 프레임워크나 라이브러리 등의 소프트웨어에서 장기간 지원되는 안정적인 버전을 의미
#
# 기업이나 대규모 프로젝트에서는 소프트웨어 업그레이드에 많은 비용과 시간이 필요하기 때문에 안정적이고 장기간 지원되는 버전이 필요
#
#
#
# **Django application**
#
# 독립적으로 작동하는 기능 단위 모듈.
#
# (각자 특정한 기능을 담당하며 다른 앱들과 함께 하나의 프로젝트를 구성)
#
#
# **앱 생성**
#
# 프로젝트를 위해 여러 개의 앱이 필요함.
#
# 하지만 포함관계는 아니고 동등한 레벨에서 생성.
#
# 등록해야함
#
# ![Alt text](image-11.png)

# %% [markdown]
# **디자인 패턴**
#
# 소프트웨어 설계에서 발생하는 문제를 해결하기 위한 일반적인 해결책
#
# (공통적인 문제를 해결하는데 쓰이는 형식화 된 관행)
#
# ### MVC 디자인 패턴
#
# (Model, View, Controller)
#
# 애플리케이션을 구조화하는 대표적인 패턴(데이터, 사용자 인터페이스, 비즈니스 로직을 분리)
#
# ->시간적 요소와 실행되는 로직을 서로 영향 없이, 독립적이고 쉽게 유지보수 할 수 있는 애플리케이션을 만들기 위해
#
# ### MTV 디자인 패턴
#
# (Model, Template, View)
#
# Django에서 애플리케이션을 구조화하는 패턴
#
# (기존 MVC패턴과 동일하나 명칭만 다름) Template -> View, View -> Controller
#
# ++ 프로젝트 구조 등 다시정리~!~!
#
# ![Alt text](image-12.png)
#
# admin.py models.py views.py 만 건드릴거임
#
# Django와 요청, 응답 사이클 기억
#
# urls.py -> project에 있음. urlpatters ->
#
# ![Alt text](image-13.png)
#
# ![Alt text](image-14.png)
#
# ![Alt text](image-15.png)
#
# ![Alt text](image-16.png)

# %% [markdown]
# settings 에 apps 추가
# for , if endfor endif 꼭 같이 써주기
# 함수명이랑 함수 내 변수명 같이쓰면안됨 바보바보
