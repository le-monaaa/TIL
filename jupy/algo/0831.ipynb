# %% [markdown]
# ### 조합 Combination
#
#     서로 다른 n개의 원소 중 r개를 순서 없이 골라낸 것.
#
# ![image.png](attachment:image.png)
#
# 재귀 호출을 이용한 조합 생성 알고리즘
#
# ![image-2.png](attachment:image-2.png)
#
# nCr 에서 n < r 인 경우 성립 X
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %%
# 0831 라이브 조합

def nCr(n, r):
    if r == 0:
        print(tr)
    elif n < r: # 남은 원소보다 많은 원소를 선택해야 하는 경우
        return  # 불가능!
    else:
        tr[r-1] = a[n-1] # a[n-1]을 조합에 포함시키는 경우
        nCr(n-1, r-1)
        nCr(n-1, r) # a[n-1]을 포함시키지 않는 경우


n = 5
r = 3
a = [1, 2, 3, 4, 5]
tr = [0] * r
nCr(n, r)

# %% [markdown]
# 10개의 원소 중 3개를 고르는 조합
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-3.png](attachment:image-3.png)
#
#
# comb -> 내가 선택한 조합을 저장한 배열
#
# r == 0 -> 더 이상 고를 게 없을 때

# %%
def nCr(n, r, s): # n개에서 r개를 고르는 조합. s: 선택할 수 있는 구간의  시작
    if r == 0:
        print(*comb)
    else:
        for i in range(s, n-r+1):
            comb[r-1] = a[i]
            nCr(n, r-1, r)

a = [1, 2, 3, 4, 5]
n = len(a)
r = 3
comb = [0]*r

# n개 중에 2개 뽑는 경우 -> 2중 for문
# 3개 뽑는 경우 -> 3중 for 문
# 근데 r개 뽑는 경우? 이렇게 해야댐..

# %% [markdown]
# 연습문제 3
#
# 부분집합의 합 문제 구현하기
#
# ![image.png](attachment:image.png)
#
# - 바이너리 카운팅 / 재귀 활용 가능

# %% [markdown]
# ### 탐욕 알고리즘
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# **동작과정**
#
# 1. 해 선택: 현 상태에서 부분 문제의 최적 해를 구한 뒤, 이를 부분해집합(solution set)에 추가한다
#
# 2. 실행 가능성 검사: 새로운 부분 해 집합이 실행 가능한지를 확인. 곧, 문제의 제약 조건을 위반하지 않는지 검사
#
# 3. 해 검사: 새로운 부분 해 집합이 문제의 해가 되는지를 확인. 아직 전체 문제의 해가 완성되지 않았다면 1의 해 선택부터 다시 시작.
#
# ![image-4.png](attachment:image-4.png)
#
#
# **최적 해를 반드시 구한다는 보장이 없다**
#
# ![image-5.png](attachment:image-5.png)
#
# --> 이런 경우 순서대로 탐색 해 내려오기 때문에 400원 2개로 해결되는 경우보다 500원이 먼저 사용되어서 안 됨
#
# --> 탐욕적인 방법은 같은 문제라도 조건에 따라 적용 될 수도, 적용 되지 않을 수도 있다
#
# --> 이런 경우 완전 탐색을 하는 수 밖에 없음
#
# **- knapsack**
#
# ![image-6.png](attachment:image-6.png)
#
# 완전 탐색하면 풀 수는 있지만 물건의 개수가 많아진다면--> 부분집합이 엄청 늘어나겠죠~~
#
# - knapsack 문제의 정형적 정의
#
# ![image-7.png](attachment:image-7.png)
#
# 부분집합의 원소들의 합(무게의 합)이 배낭 무게 이하면서, 선택 원소들의 가치의 합이 최대가 되도록 부분집합을 결정하는 문제.
#
# **kanpsack 문제 유형**
#
# ![image-8.png](attachment:image-8.png)
#
# fractional knapsack -> 그리디로 풀 수 있음
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-12.png](attachment:image-12.png)
#
# 가치 기준 탐욕적 방법, 무게 기준 탐욕적 방법, kg당 가치 기준 탐욕적 방법 -> 최적해 x
#
# --> 0-1 knapsack은 탐욕적 방법으로 풀 수 없다. 특정 조건마다 설정해주ㅓ야함.
#
#
# ![image-13.png](attachment:image-13.png)
#
# --> fractional knapsack 은 greedy로 풀 수 있음
#
# 문제의 조건에 따라 맞는 방법을 잘 찾는 게 중요하다
#
# **- 활동 선택 문제**
#
# **회의실 배정하기**
#
# ![image-14.png](attachment:image-14.png)
#
# 모든 회의에 대한 부분집합을 구하면 풀 수는 있지만 입력이 커지면 연산이 엄청많아진다.!
#
# ![image-15.png](attachment:image-15.png)
#
# ![image-16.png](attachment:image-16.png)
#
# ![image-17.png](attachment:image-17.png)
#
# 종료시간이 가장 빠른 것을 선택, 그리고 다음 것을 선택할 때, 이전 활동이 끝난건지 체크
# 이전에 선택했던 활동의 이후에 시작하는가를 확인
