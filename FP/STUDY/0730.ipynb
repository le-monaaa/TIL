# %% [markdown]
# sequence types - str, list, tuple, range
#
# : 순서o, 인덱싱o, 슬라이싱o, 길이o, iterable
#
# *str : 문자들의 순서가 있는 변 경 불 가 능 한 시퀀스 자료형
#
# \[list] : 어떤 자료형도 저장할 수 있음(str, int, float, list, dictionary, ...)
#
# (tuple) : 파이썬은 쉼표를 튜플 생성자로 사용해 괄호는 생략이 가능하다.
#
# {set} : 합집합 set1 | set2 , 차집합 set1- set2 , 교집합 set1 & set2
#
#
# collection- str(im, sequence), list(mu, sequence), tuple(im, sequence), set(mu, non-se), dict(non-se, mu)
#
# :여러 개의 항목 또는 요소를 담는 자료 구조
#
#
# 암시적형변환 : Boolean, NumericType에서 적용
#
# **명시적 형변환** Explic Type conversion
#
# 개발자가 직접 형변환을 하는 것. 암시적 형변환을 제외한 모든 경우
#
# Str -> integer : 형식에 맞는 숫자만 가능
# integer -> str : 모두 가능
#
# int(3.5) -> 3으로 저장.
# 하지만 변환은 안됨.
#
# ![image.png](attachment:image.png)
#
# **연산자**
#
# is : reference 비교. is는 되도록이면 boolean 비교할 때 사용
# == : 값 비교.
#
# 시퀀스형 연산자// 산술연산자 +와 *는 시퀀스에서 사용되면 산술연산자와 다른 역할을 가진다.
