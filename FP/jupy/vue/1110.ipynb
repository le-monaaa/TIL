# %% [markdown]
# ![image.png](attachment:image.png)
#
# 세션 - 사용자 인증 정보
#
# 쿠키 - 서버로부터 받고-주고 할 정보
#
# 임시로 데이터를 저장할 공간-- 브라우저의 스토리지.
#
# local storage- 브라우저의 저장소 중 하나로
# 반영구적으로 브라우저에 저장할 수 있는 공간
# 반영구적으로?? -> 브라우저를 껐다 켜도 데이터가 유지됨.
# (세션은 브라우저를 끄면 삭제됨)
# local storage는 껐다 켜도 유지됨. 크롬 기준으로 5MB정도의 데이터를 저장할 수 있고 쿠키보다 많은 데이터를 저장할 수 있다.
# 보안면에서 조금 위험--최대한 위험 수준이 낮은 데이터만 저장.
# 문자열만 저장 가능
#
# 브라우저 쪽에 임시로 저장하고 싶은 데이터가 있고 보안 수준이 낮다?
# --> 로컬 스토리지에 저장
