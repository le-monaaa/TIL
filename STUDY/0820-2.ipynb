# %% [markdown]
# reference
#
# [자료구조] 힙(heap)이란? https://gmlwjd9405.github.io/2018/05/10/data-structure-heap.html
#
# [알고리즘] 힙 정렬(heap sort)이란? https://gmlwjd9405.github.io/2018/05/10/algorithm-heap-sort.html
#
# 완전이진트리 배열에 저장하기 https://lordofkangs.tistory.com/139
#
# 이진트리 및 완전이진트리 구현과 순회 https://seongonion.tistory.com/41

# %% [markdown]
# # 트리
#
# ### 트리의 개념
#
# - 비선형, 1:n 관계, 계층형 자료구조, 상위->하위로 내려가며 확장되는 나무형 구조
#
# ### 트리의 정의
#
# - 한 개 이상의 노드로 이루어진 유한 집합.
#
#     - root : 노드 중 최상위 노드
#
#     - 나머지 노드들은 n(>=0)개의 분리 집합으로 분리될 수 있다.
#
# - T1, T2, ... ,TN은 각각 하나의 트리가 되며(재귀적 정의) 루트의 부 트리(subtree)라 함
#
# ![image.png](attachment:image.png)
#
# **용어정리**
#
# 노드(node): 트리의 원소
#
# 간선(edge): 노드를 연결하는 선. 부모와 자식 노드를 연결
#
# 루트 노드(root node): 트리의 시작 노드
#
# 형제 노드(sibling node): 같은 부모 노드의 자식 노드들
#
# 조상 노드: 간선을 따라 루트 노드까지 이르는 경로에 있는 모든 노드들(루트포함)
#
# 서브 트리(sub tree): 부모 노드와 연결된 간선을 끊었을 때 생성되는 트리
#
# 자손 노드: 서브 트리에 있는 하위 레벨의 노드들
#
# 차수(degree)
#
# - 노드의 차수: 노드에 연결된 자식 노드의 수
#
# - 트리의 차수: 트리에 있는 노드의 차수 중 가장 큰 값
#
# - 단말 노드(리프 노드): 차수가 0인 노드. 자식 노드가 없는 노드
#
# 높이
#
# - 노드의 높이: 루트에서 노드에 이르는 간선의 수. 노드의 레벨
#
# - 트리의 높이: 트리에 있는 노드의 높이 중 가장 큰 값. 최대 레벨.
#
# 루트노드의 레벨 0
#
# ![image-3.png](attachment:image-3.png)
#
#
# ### 이진트리
#
# 모든 노드들이 2개의 서브트리를 갖는 특별한 형태의 트리
#
# 각 노드가 자식 노드를 최대 2개까지만 갖는 트리
#
# 이진트리의 예
#
# ![image-2.png](attachment:image-2.png)
#
# **이진트리의 특성**
#
# 레벨 i에서의 노드의 최대 개수는 2^i 개.
#
# 높이가 h인 이진 트리가 가질 수 있는 노드의 최소 개수는 h+1개. 최대 개수는 2^(h+1)-1 개
#
# ![image.png](attachment:image.png)
#
# 레벨 i에서의 노드의 최대 개수는 2^i개.
#
# 높이가 h인 이진 트리가 가질 수 있는 노드의 최소 개수는 h+1개.
#
# 최대 개수는 (2^(h+1)-1)개.
#
# # 이진 트리 종류
#
# 1. 포화 이진 트리(Full Binary Tree)
#
#  모든 레벨에 노드가 포화상태로 차 있는 이진 트리
#
#  높이가 h일 때, 최대의 노드 개수인 (2^(h+1)-1)개의 노드를 가진 이진 트리.
#
#  루트를 1번으로 해 2^(h+1)-1까지 정해진 위치에 대한 노드 번호 가짐.
#
# 2. 완전 이진 트리(Complete Binary Tree)
#
#  높이가 h이고 노드 수가 n개일 때 (단 2^h <= n <=2(h+1)-1), 포화 이진 트리의 노드 번호가 1번부터 n번까지 빈 자리가 없는 이진 트리
#
# ![image-2.png](attachment:image-2.png)
#
# 3. 편향 이진 트리(Skewed Binary Tree)
#
#  높이 h에 대한 최소 개수의 노드를 가지면서 한쪽 방향의 자식 노드만을 가진 이진 트리
#
#  ![image-3.png](attachment:image-3.png)
#
#  정말 편향적이다 !
#
# ### 이진트리의 순회
#
# 순회 : 트리의 각 노드를 중복되지 않게 전부 방문하는 것
#
#         트리는 비선형구조이기에 선형구조처럼 선후 연결 관계를 알 수 없다
#
#         -> 모르면 됐지 꼭 방법을 찾는다
#
# 순회! : 트리의 노드들을 체계적으로 방문하는 것
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# **순회방법**
#
# 1. 전위순회(preorder traversal): VLR
#
#     부모노드 방문 후 자식노드를 좌, 우 순서로 방문
#
# 2. 중위순회(inorder traversal): LVR
#
#     왼쪽 자식노드, 부모노드, 오른쪽 자식노드 순으로 방문
#
# 3. 후위순회(postorder traversla): LRV
#
#     자식노드를 좌우 순서로 방문한 후, 부모노드로 방문
#
# **전위순회**
#
# 1. 현재 노드 n을 방문하여 처리한다. V
#
# 2. 현재 노드 n의 왼쪽 서브트리로 이동한다 L
#
# 3. 현재 노드 n의 오른쪽 서브트리로 이동한다 R
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
#
# **중위순회**
#
# 1. 현재 노드n의 왼쪽 서브트리로 이동 L
#
# 2. 현재 노드n을 방문하여 처리한다. V
#
# 3. 현재 노드n의 오른쪽 서브트리로 이동한다. R
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# **후위순회**
#
# 1. 현재 노드n의 왼쪽 서브트리로 이동 L
#
# 2. 현재 노드n의 오른쪽 서브트리로 이동 R
#
# 3. 현재 노드n을 방문하여 처리한다 V
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-11.png](attachment:image-11.png)
#
#
# 연습문제
#
# ![image-12.png](attachment:image-12.png)
#
# 내 예상 순서
#
# 전위: A B D H I E J C F K G L M
# A D B E C F G
#
# 중위: H D I B J E A K F C L G M
# D B E A F C G
#
# 후위: H I D J E B K F L M G C A
# D E B F G C A

# %% [markdown]
# ### 이진트리의 표현
#
# ![image.png](attachment:image.png)
#
# - 루트의 번호를 1로 함
#
# - 레벨 n에 있는 노드에 대해 왼쪽부터 오른쪽으로 2^n부터 2^(n+1)-1 까지 번호를 차례로 부여함
#
# **배열을 이용한 이진트리의 표현**
#
# - 노드 번호의 성질
#
#     ![image-2.png](attachment:image-2.png)
#
#     노드 번호가 i인 노드의 부모 노드 번호는? i//2
#
#     노드 번호가 i인 노드의 자식 노드 번호는? 왼쪽 i * 2, 오른쪽 i * 2 + 1
#
#     레벨 n의 노드 시작 번호는 2^n
#
#     --> 완전, 포화 이진 트리가 아닌 경우에도 적용이 되는가??
#
#         다음 화면 자료를 보니까 그냥 빈자리는 비우는 것 같다 --> 맞는지 확인하기
#
# - 노드 번호를 배열의 인덱스로 활용함
#
#     높이가 h인 이진 트리를 위한 배열의 크기?
#
#     - 레벨 i의 최대 노드 수는? 2^i
#
#     --> 1 + 2 + 4 + 8 + ... 2^i = 2^(h+1) -1
#
#     ![image-3.png](attachment:image-3.png)
#
#
#     ![image-4.png](attachment:image-4.png)
#
#     포화 이진 트리: 루트가 1. 하지만 이진트리라고 루트가 0이라는 보장은 없음.

# %% [markdown]
# **구현**
#
# 이진트리는 보통 리스트로 구현됨. 완전이진트리는 배열도 유용함.
#
# 완전이진트리: 좌측부터 빠짐없이 노드가 채워진 트리. 중간에 빈 부분이 없어 배열이 낭비되지x
#
# --> 배열을 이용한다면 주의할점!!!! 계층의 개념 유의. 막넣으면 안됩니당
#
# 큐가 언급되는 이유-- 완전이진트리의 노드의 우선순위대로 채워져야 하는 부분이..
#
# 부모와 자식간의 인덱스 규칙을 잘 알고 삽입해야 함
#
# ![image-2.png](attachment:image-2.png)
#
#
# ++++++
#
# 트리는 무조건 단방향인가??? 계층형이기 때문에 단방향 일 수 밖에 없다. 양방향이면 그냥 그래프
#
# 버블, 퀵, 병합은 모든 데이터가 동등한 지위, but 힙은 계층구조-->탐색에 유용.
#
# 선택정렬을 응용한 힙 정렬에는 알맞은 구조이다~
#
# ### 이진 트리의 저장
#
# - 부모 번호를 인덱스로 자식 번호를 저장
#
# ![image.png](attachment:image.png)
#
# - 자식 번호를 인덱스로 부모 번호를 저장
#
# ![image-3.png](attachment:image-3.png)
#
# --->이게 무슨 의미인지 모르겠음
#
# - 루트 찾기, 조상 찾기
#
# ![image-4.png](attachment:image-4.png)
#
# **배열을 이용한 이진 트리 표현의 단점**
#
# - 편향 이진 트리의 경우에 사용하지 않는 배열 원소에 대한 메모리 공간 낭비 발생
#
# - 트리의 중간에 새로운 노드를 삽입하거나 기존의 노드를 삭제할 경우 배열의 크기 변경이 어려워 비효율적

# %%
complete_binary_tree = [None, 2, 1, 5, 1, 3]

# 부모 노드의 인덱스 위치를 구하는 함수
def get_parent_index(tree, index):
    if index != 1: # 입력된 자식노드 인덱스가 root 인덱스가 아니라면
        return index//2
    else: # 입력된 자식노드 인덱스가 root 인덱스라면
        return None
    
# 왼쪽 자식 노드의 위치를 구하는 함수
def get_left_child_index(tree, index):
    # 자식 노드가 있어야 할 자리가 트리의 길이를 벗어나지 않는다면 
    if index * 2 <= len(tree):
        return index*2
    else:
        return None
    
# 오른쪽 자식 노드의 위치를 구하는 함수
def get_right_child_idex(tree, index):
    if index * 2 + 1 <= len(tree):
        return index*2 + 1
    else:
        return None

# %%
# 전위순회 구현

def pre_order(node):
    print(node.data)

    if node.left_child != None:
        pre_order(node.left_child)

    if node.right_child != None:
        pre_order(node.right_child)


# 후위순회 구현

def post_order(node):
    if node.left_child != None:
        post_order(node.left_child)

    if node.right_child != None:
        post_order(node.right_child)
        
    print(node.data)    
        
# 중위순회 구현

def in_order(node):
    if node.left_child != None:
        in_order(node.left_child)

    print(node.data)

    if node.right_child != None:
        in_order(node.right_child)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 연결리스트
#
#  배열을 이용한 이진 트리의 표현의 단점을 보완하기 위해 연결리스트를 이용해 트리를 표현할 수 있다
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 수식 트리
#
# 수식을 표현하는 이진 트리. 수식 이진 트리라고 부르기도 함
#
# 연산자는 루트 노드이거나 가지 노드. 피연산자는 모두 잎 노드
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 이진 탐색 트리
#
# 탐색작업을 효율적으로 하기 위한 자료구조
#
# 모든 원소는 서로 다른 유일한 키를 갖는다
#
# key(왼쪽 서브트리) < key(루트 노드) < key(오른쪽 서브트리)
#
# 왼쪽 서브트리와 오른쪽 서브트리도 이진 탐색 트리다
#
# 중위 순회하면 오름차순으로 정렬된 값을 얻을 수 있다.
#
# ![image.png](attachment:image.png)
#
# **탐색연산**
#
# 루트에서 시작
#
# 탐색할 키 값 x를 루트 노드의 키 값과 비교
#
# (키 값 x = 루트노드의 키 값) -> 원하는 원소를 찾음. 탐색연산 성공
# (키 값 x < 루트노드의 키 값) -> 루트노드의 왼쪽 서브트리에 대해 탐색연산 수행
# (키 값 x > 루트노드의 키 값) -> 루트노드의 오른쪽 서브트리에 대해 탐색연산 수행
#
# ![image-2.png](attachment:image-2.png)
#
# **삽입연산**
#
# 1. 먼저 탐색 연산을 수행
#
#     삽입할 원소와 같은 원소가 트리에 있으면 삽입할 수 없으므로, 같은 원소가 트리에 있는지 탐색해 확인
#
#     탐색에서 탐색 실패가 결정되는 위치가 삽입 위치.
#
# 2. 탐색 실패한 위치에 원소를 삽입한다
#
#     ![image-3.png](attachment:image-3.png)
#
# **성능**
#
# 탐색, 삽입, 삭제 시간은 트리의 높이 만큼 시간이 걸림
# O(h) h: BST의 깊이.
#
# 평균의 경우
#
#     -이진 트리가 균형적으로 생성되어 있는 경우
#
#     -O(log n)
#
# 최악의 경우
#
#     -한쪽으로 치우친 경사 이진트리의 경우
#
#     -O(n)
#
#     -순차탐색과 시간복잡도가 같음.
#
#
# ![image-4.png](attachment:image-4.png)
#
# **삭제연산**
#
# 삽입처럼 똑같이 탐색해서 만났을 때 0으로 바꿔버리면 될 듯
#
# 이론은 완 벽

# %% [markdown]
# ### heap
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# 완전 이진 트리의 일종. 우선순위 큐를 위해 만들어진 자료 구조
#
# *우선순위 큐: 우선순위의 개념을 큐에 도입한 자료 구조
#
# - 이용 사례: 시뮬레이션 시스템, 네트워크 트래픽 제어, 수치 해석적인 계산
#
# - 구현: 배열, 연결리스트, 힙으로 구현 가능. 힙이 가장 효율적
#
# **heap**
#
# 여러 개의 값들 중에서 최댓값이나 최솟값을 빠르게 찾아내도록 만들어진 자료 구조
#
# 일종의 반정렬상태(느슨한 정렬 상태)를 유지함.
#
# 큰 값이 상위 레벨에 있고, 작은 값이 하위 레벨에 있음.
#
# (부모 노드의 키 값이 자식 노드의 키 값보다 항상 큰(작은) 이진 트리)
#
# 중복값 허용함.(+이진 탐색 트리에서는 중복된 값 허용하지 않음)
#
# **heap의 종류**
#
# - 최대 힙(max heap): 부모 노드의 키 값이 자식 노드의 키 값보다 크거나 같은 완전 이진 트리
#
#     (부모노드의 key) >= (자식노드의 key)
#
# - 최소 힙(min heap): 부모 노드의 키 값이 자식 노드의 키 값보다 작거나 같은 완전 이진 트리
#
#     (부모노드의 key) <= (자식노드의 key)
#
#     ![image.png](attachment:image.png)
#
#
# **heap의 구현**
#
# - 표준 자료구조는 배열.
#
# - 배열의 첫 번째 인덱스인 0은 사용x (구현의 편의성때문에)
#
# - 특정 위치의 노드 번호는 새로운 노드가 추가되어도 변하지 X
#
#     (루트 노드의 오른쪽 노드의 번호는 항상 3)
#
# - 힙에서의 부모 노드와 자식 노드의 관계
#
#     왼쪽 자식의 인덱스 = (부모의 인덱스) * 2
#     오른쪽 자식의 인덱스 = (부모의 인덱스) * 2 + 1
#     부모의 인덱스 = (자식의 인덱스) / 2
#
# **힙의 삽입**
#
# 1. 힙에 새로운 요소가 들어오면 -> 일단 새로운 노드를 힙의 마지막 노드에 이어서 삽입함.
#
# 2. 새로운 노드를 부모 노드들과 교환해서 힙의 성질을 만족시킴 (와 듣기만해도 귀찬핟)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# **힙의 삭제**
#
# 1. 최대 힙에서 최댓값은 루트 노드이므로 루트 노드가 삭제됨.
#
#     최대힙에서 삭제 연산은 최댓값을 가진 요소를 삭제하는 것
#
# 2. 삭제된 루트 노드에는 힙의 마지막 노드를 가져온다.
#
# 3. 힙을 재구성한다.
#
# max heap에서 최댓값을 삭제하는 방법
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# **힙 연산-삭제**
#
# 힙에서는 루트 노드의 원소만을 삭제할 수 있다
#
# 루트 노드의 원소를 삭제하여 반환함
#
# 힙의 종류에 따라 최대값 혹은 최소값을 구할 수 있음
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ### 힙 정렬 (heap sort)
#
# 최대 힙 트리나 최소 힙 트리를 구성해 정렬을 하는 방법
#
# 내림차순 정렬을 위해서는 최대 힙을 구성하고 오름차순 정렬을 위해서는 최소 힙을 구성
#
# **과정**
#
# 1. 정렬해야 할 n개의 요소들로 최대 힙(완전이진트리/내림차순)을 만듦
#
# 2. 한 번에 하나씩 요소를 힙에서 꺼내서 배열의 뒤부터 저장
#
# 3. 삭제되는 요소들(최댓값부터 삭제)은 값이 감소되는 순서로 정렬됨
#
# **내림차순 정렬을 위한 max heap의 구현**
#
# - heap은 1차원 배열로 쉽게 구현 가능 (휴 다행)
#
# - 정렬해야 할 n개의 요소들을 1차원 배열에 기억하고 최대 힙 삽입을 통해 차례대로 삽입함
#
# - 최대 힙으로 구성된 배열에서 최댓값부터 삭제
#
# **heap sort 알고리즘의 특징**
#
# - 시간 복잡도가 괜찮다 nlong2n
#
# - 힙 정렬이 가장 유용한 경우는 전체 자료 정렬x 가장 큰 값 몇 개만 가져올 때
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 트리: 노드로 이루어진 비선형 자료구조. 1대 다의 형태. 노드와 노드들을 연결하는 간선들로 이루어져있음
#
# 트리는 계층적 구도. 사이클이 존재할 수 없음.
#
# 이진트리: 각 노드가 최대 두 개의 자식을 갖는 트리
#
# 완전 이진트리: 마지막 레벨을 제외하고 모든 레벨이 완전히 채워진 트리. 왼쪽우선.
#
# 전 이진트리: 모든 노드가 0개 또는 2개의 자식 노드를 갖는 트리
#
# 포화 이진트리: 모든 레벨이 노드로 꽉 차있는 트리. 전 이진트리의 성질도 만족해야 함.
#
# 이진 탐색트리: 이진트리이면서 key가 모두 유일한 값을 가지고 부모의 키가 왼쪽 자식 노드 키보다 크고 오른쪽 자식 노드의 키보다 작음. 왼쪽, 오른쪽 서브트리도 이진 탐색 트리인 트리.

# %% [markdown]
# 이진트리: 이진트리
# 완전이진트리: 마지막 레벨 제외 모든 레벨이 완전히 채워진 트리
# 포화이진트리: 모든 레벨이 노드로 꽉 차있는 트리
# 전 이진트리: 모든 노드가 0 or 2개의 자식노드를 가지는 트리
# 이진 탐색트리: 이진트리이면서
# 1) key의 유일성 만족
# 2) 왼쪽자식노드key < 부모노드key<오른쪽자식노드key
# 3) 왼, 오른쪽 서브트리도 이진탐색트리인 트리
#
# heap: 최댓값, 최솟값을 빠르게 찾아내기 위한 구조. 반정렬(max기준 큰값이 상위레벨, 작은값이 하위레벨이나 완전한 정렬은 아님), 중복값허용(이진탐색트리에서는 중복값 허용x)
#
# 1) max heap: 부모노드key>= 자식노드key
# 2) min_heap: 자식노드key<= 부모노드key
#
# 삽입: 일단 마지막 노드에 이어서 삽입(last+1). 새로운 노드를 부모노드들과 비교해 힙의 성질 만족시킴
# 삭제: 대상-루트노드. 힙의 마지막 노드(last)를 기준으로 시작해 다시 정렬
