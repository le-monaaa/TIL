# %% [markdown]
# # APS 기본
# ### 배열 1(Array 1)
#
# - 알고리즘
# - 배열
# - 버블 정렬 (Bubble sort)
# - 카운팅 정렬 (Counting sort)
# - 완전검색
# - 그리디 (Greedy Algorithm)

# %% [markdown]
# - 알고리즘 : 어떤 문제를 해결하기 위한 절차.
#
# **보다 좋은 알고리즘 이해, 활용하기 !!**
#
# #### 어떤 알고리즘이 좋은 알고리즘인가!
#
# - 정확성
#
# - 작업량 : 얼마나 적은 연산으로 원하는 결과를 얻어내느냐
#
# - 메모리 사용량 : 얼마나 적은 메모리를 사용하는가
#
# - 단순성 : 얼마나 단순한가
#
# - 최적성 : 더 이상 개선할 여지없이 최적화되었는가
#
# 주어진 문제를 해결하기 위해 여러 가지의 다양한 알고리즘을 적용할 수 있다.
#
# --> 어떤 알고리즘을 사용해야 하는가?
#
# 알고리즘의 성능 분석 필요.
#
# -- 많은 문제에서 성능 분석의 기준으로 알고리즘의 작업량을 비교함
#
# 알고리즘 작업량의 표현
#
# : 시간복잡도 - 실제 걸리는 시간을 측정, 실행되는 명령문의 갯수를 계산
#
# #### 빅-오(O) 표기법 (Big-Oh Notation)
#
# 시간복잡도를 표현하는 방법.
#
# 시간 복잡도 함수 중에서 가장 큰 영향력을 주는 n에 대한 항만을 표시.
# 계수(Coefficient) 는 생략.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 배열
#
# 배열 : 일정한 자료형의 변수들을 하나의 이름으로 열거해 사용하는 자료구조
#
# **배열의 필요성**
#
# - 프로그램 내에서 여러 개의 변수가 필요할 때, 일일이 다른 변수명을 이용해 작업을 처리하는 것은 비효율적
#
# - 배열을 사용하면 하나의 선언으로 둘 이상의 변수 선언 가능
#
# - 단순히 다수 변수 선언에만 국한 x, 다수의 변수로는 하기 힘든 작업을 배열을 활용해 쉽게 할 수 있다.
#
#
# **1차원 배열의 선언**
#
# 변수에 처음 값을 할당할 때 생성
#
# 이름 : 프로그램에서 사용할 배열의 이름
#
# Arr = list(), Arr = [] Arr = [1, 2, 3] Arr = [0] * 10
#
# 이런식으로.
#
# **1차원 배열의 접근**
#
# 인덱스 활용.
# Arr[0] = 10 # 배열 Arr의 0번 원소에 10을 저장.
# Arr[idx] = 20

# %% [markdown]
# **파이썬에서 리스트와 배열의 차이**
# https://siloam72761.tistory.com/entry/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%9E%90%EB%A3%8C%EA%B5%AC%EC%A1%B0-%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%97%90%EC%84%9C-%EB%B0%B0%EC%97%B4%EA%B3%BC-%EB%A6%AC%EC%8A%A4%ED%8A%B8%EC%9D%98-%EC%B0%A8%EC%9D%B4
#
# 리스트는 배열에 속하는 것 중 하나.
#
#
# 배열은 collection.
# 대괄호, 정렬, 변경, 중복 가능
# 하지만 어떤 배열의 종류를 사용하냐에 따라 여러가지 데이터 타입이 가능할 수도 가능하지 않을 수도 있다.

# %% [markdown]
# 파이참 2020 3.5 커뮤니티 설치
#
# 파일 처음 만들고 첫 실행은 우클릭-Run
#
# 그담부터는 그냥 우측 상단 버튼 이용
#
# 왜 vs code말고 파이참을 쓰는걸까??
#
# -역량테스트 볼 때 파이썬에 허락된 IDE가 파이참이라서.
#
# 파일 이름은 영어로. 실행이 잘 안 될 수도 있다.

# %% [markdown]
# #### 정렬
#
# 2개 이상의 자료를 특정 기준에 의해 작은 값부터 큰 값(오름차순) or 내림차순으로 재배열하는 것
#
# 키 : 자료를 정렬하는 기준이 되는 특정 값
#
# 정렬 방식의 종류
#
# : 버블 정렬, 카운팅 정렬, 선택 정렬, 퀵 정렬, 삽입 정렬, 병합 정렬
#
# ##### 버블 정렬 (Bubble Sort) O(n^2)
#
# - 인접한 두 개의 원소를 비교하며 자리를 계속 교환하는 방식
#
# - 정렬 과정:
#
# 첫 번째 원소부터 인접한 원소끼리 계속 자리를 교환하면서 맨 마지막 자리까지 이동
#
# 한 단계가 끝나면 가장 큰 원소가 마지막 자리로 정렬.
#
# 교환하며 자리를 이동하는 모습이 물 위에 올라오는 거품 모양과 같다고 해서 버블 정렬이라고 한다.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 카운팅 정렬 (Counting Sort)
#
# - 항목들의 순서를 결정하기 위해 집합에 각 항목이 몇 개씩 있는지 세는 작업을 하여, 선형 시간에 정렬하는 효율적인 알고리즘
#
# - 제한:
#
# 정수나 정수로 표현할 수 있는 자료형에서만 적용 가능
# (각 항목의 발생 횟수를 기록하기 위해 정수 항목으로 인덱스 되는 카운트들의 배열을 사용하기 때문이다)
#
# - 시간 복잡도:
#
# O(n + k) : n은 리스트 길이, k는 정수의 최대값.
#
# - 정렬 과정:
